# %%
# !pip install --upgrade jupyter
# Out:
# Requirement already satisfied: jupyter in c:\users\work\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: notebook in c:\users\work\anaconda3\lib\site-packages (from jupyter) (6.4.12)
# Requirement already satisfied: qtconsole in c:\users\work\anaconda3\lib\site-packages (from jupyter) (5.2.2)
# Requirement already satisfied: jupyter-console in c:\users\work\anaconda3\lib\site-packages (from jupyter) (6.4.3)
# Requirement already satisfied: nbconvert in c:\users\work\anaconda3\lib\site-packages (from jupyter) (6.4.4)
# Requirement already satisfied: ipykernel in c:\users\work\anaconda3\lib\site-packages (from jupyter) (6.15.2)
# Requirement already satisfied: ipywidgets in c:\users\work\anaconda3\lib\site-packages (from jupyter) (7.6.5)
# Requirement already satisfied: debugpy>=1.0 in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.5.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (7.31.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (1.5.5)
# Requirement already satisfied: packaging in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (21.3)
# Requirement already satisfied: psutil in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (6.3.2)
# Requirement already satisfied: traitlets>=5.1.0 in c:\users\work\anaconda3\lib\site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\work\anaconda3\lib\site-packages (from ipywidgets->jupyter) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\work\anaconda3\lib\site-packages (from ipywidgets->jupyter) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\work\anaconda3\lib\site-packages (from ipywidgets->jupyter) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\work\anaconda3\lib\site-packages (from ipywidgets->jupyter) (1.0.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\work\anaconda3\lib\site-packages (from jupyter-console->jupyter) (3.0.20)
# Requirement already satisfied: pygments in c:\users\work\anaconda3\lib\site-packages (from jupyter-console->jupyter) (2.15.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: jinja2>=2.4 in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (2.11.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: jupyter-core in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.11.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.4)
# Requirement already satisfied: bleach in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: testpath in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.6.0)
# Requirement already satisfied: defusedxml in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (4.11.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\work\anaconda3\lib\site-packages (from nbconvert->jupyter) (0.5.13)
# Requirement already satisfied: argon2-cffi in c:\users\work\anaconda3\lib\site-packages (from notebook->jupyter) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\work\anaconda3\lib\site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\work\anaconda3\lib\site-packages (from notebook->jupyter) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\work\anaconda3\lib\site-packages (from notebook->jupyter) (0.14.1)
# Requirement already satisfied: qtpy in c:\users\work\anaconda3\lib\site-packages (from qtconsole->jupyter) (2.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\work\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (68.0.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\work\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.1)
# Requirement already satisfied: decorator in c:\users\work\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\work\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: backcall in c:\users\work\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: colorama in c:\users\work\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.5)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\work\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert->jupyter) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\work\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\work\anaconda3\lib\site-packages (from jupyter-core->nbconvert->jupyter) (302)
# Requirement already satisfied: fastjsonschema in c:\users\work\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\work\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter) (4.16.0)
# Requirement already satisfied: wcwidth in c:\users\work\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\work\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\work\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\work\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.3.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\work\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\work\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\work\anaconda3\lib\site-packages (from packaging->ipykernel->jupyter) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\work\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\work\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\work\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->jupyter) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\work\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\work\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter) (2.21)

# %%
import sys
sys.stdout.encoding = 'utf-8'

# !pip install .
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 73, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 491, in collect_root_requirements
#     req = self._make_requirement_from_install_req(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 453, in _make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 293, in __init__
#     super().__init__(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 485, in prepare_linked_requirement
#     self._log_preparing_link(req)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 289, in _log_preparing_link
#     logger.info(message, information)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Processing %s'
# Arguments: ('c:\\users\\work\\macromedia\\my_projekt_python_semester2\\05_github_ver\xf6ffentlichung\\password_package',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 73, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 491, in collect_root_requirements
#     req = self._make_requirement_from_install_req(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 453, in _make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 293, in __init__
#     super().__init__(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 516, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 631, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 69, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 38, in prepare_distribution_metadata
#     self._prepare_build_backend(finder)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 70, in _prepare_build_backend
#     self.req.build_env.install_requirements(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\build_env.py", line 217, in install_requirements
#     self._install_requirements(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\build_env.py", line 274, in _install_requirements
#     with open_spinner(f"Installing {kind}") as spinner:
#   File "C:\Users\Work\anaconda3\lib\contextlib.py", line 119, in __enter__
#     return next(self.gen)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 125, in open_spinner
#     spinner = NonInteractiveSpinner(message)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 80, in __init__
#     self._update("started")
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 85, in _update
#     logger.info("%s: %s", self._message, status)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: '%s: %s'
# Arguments: ('Installing build dependencies', 'started')
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 73, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 491, in collect_root_requirements
#     req = self._make_requirement_from_install_req(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 453, in _make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 293, in __init__
#     super().__init__(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 516, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 631, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 69, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 38, in prepare_distribution_metadata
#     self._prepare_build_backend(finder)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 70, in _prepare_build_backend
#     self.req.build_env.install_requirements(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\build_env.py", line 217, in install_requirements
#     self._install_requirements(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\build_env.py", line 275, in _install_requirements
#     call_subprocess(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\subprocess.py", line 203, in call_subprocess
#     spinner.finish("done")
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 97, in finish
#     self._update(f"finished with status '{final_status}'")
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 85, in _update
#     logger.info("%s: %s", self._message, status)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: '%s: %s'
# Arguments: ('Installing build dependencies', "finished with status 'done'")
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 73, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 491, in collect_root_requirements
#     req = self._make_requirement_from_install_req(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 453, in _make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 293, in __init__
#     super().__init__(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 516, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 631, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 69, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 48, in prepare_distribution_metadata
#     self._install_build_reqs(finder)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 118, in _install_build_reqs
#     build_reqs = self._get_build_requires_wheel()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 95, in _get_build_requires_wheel
#     return backend.get_requires_for_build_wheel()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 692, in get_requires_for_build_wheel
#     return super().get_requires_for_build_wheel(config_settings=cs)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 166, in get_requires_for_build_wheel
#     return self._call_hook('get_requires_for_build_wheel', {
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 311, in _call_hook
#     self._subprocess_runner(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\subprocess.py", line 251, in runner
#     with open_spinner(message) as spinner:
#   File "C:\Users\Work\anaconda3\lib\contextlib.py", line 119, in __enter__
#     return next(self.gen)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 125, in open_spinner
#     spinner = NonInteractiveSpinner(message)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 80, in __init__
#     self._update("started")
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 85, in _update
#     logger.info("%s: %s", self._message, status)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: '%s: %s'
# Arguments: ('Getting requirements to build wheel', 'started')
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 73, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 491, in collect_root_requirements
#     req = self._make_requirement_from_install_req(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 453, in _make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 293, in __init__
#     super().__init__(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 516, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 631, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 69, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 48, in prepare_distribution_metadata
#     self._install_build_reqs(finder)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 118, in _install_build_reqs
#     build_reqs = self._get_build_requires_wheel()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 95, in _get_build_requires_wheel
#     return backend.get_requires_for_build_wheel()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 692, in get_requires_for_build_wheel
#     return super().get_requires_for_build_wheel(config_settings=cs)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 166, in get_requires_for_build_wheel
#     return self._call_hook('get_requires_for_build_wheel', {
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 311, in _call_hook
#     self._subprocess_runner(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\subprocess.py", line 252, in runner
#     call_subprocess(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\subprocess.py", line 203, in call_subprocess
#     spinner.finish("done")
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 97, in finish
#     self._update(f"finished with status '{final_status}'")
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 85, in _update
#     logger.info("%s: %s", self._message, status)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: '%s: %s'
# Arguments: ('Getting requirements to build wheel', "finished with status 'done'")
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 73, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 491, in collect_root_requirements
#     req = self._make_requirement_from_install_req(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 453, in _make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 293, in __init__
#     super().__init__(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 516, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 631, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 69, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 61, in prepare_distribution_metadata
#     self.req.prepare_metadata()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\req_install.py", line 555, in prepare_metadata
#     self.metadata_directory = generate_metadata(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\build\metadata.py", line 35, in generate_metadata
#     distinfo_dir = backend.prepare_metadata_for_build_wheel(metadata_dir)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 713, in prepare_metadata_for_build_wheel
#     return super().prepare_metadata_for_build_wheel(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 186, in prepare_metadata_for_build_wheel
#     return self._call_hook('prepare_metadata_for_build_wheel', {
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 311, in _call_hook
#     self._subprocess_runner(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\subprocess.py", line 251, in runner
#     with open_spinner(message) as spinner:
#   File "C:\Users\Work\anaconda3\lib\contextlib.py", line 119, in __enter__
#     return next(self.gen)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 125, in open_spinner
#     spinner = NonInteractiveSpinner(message)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 80, in __init__
#     self._update("started")
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 85, in _update
#     logger.info("%s: %s", self._message, status)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: '%s: %s'
# Arguments: ('Preparing metadata (pyproject.toml)', 'started')
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 73, in resolve
#     collected = self.factory.collect_root_requirements(root_reqs)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 491, in collect_root_requirements
#     req = self._make_requirement_from_install_req(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 453, in _make_requirement_from_install_req
#     cand = self._make_candidate_from_link(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 293, in __init__
#     super().__init__(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 156, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 225, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 304, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 516, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 631, in _prepare_linked_requirement
#     dist = _get_prepared_distribution(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 69, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\distributions\sdist.py", line 61, in prepare_distribution_metadata
#     self.req.prepare_metadata()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\req_install.py", line 555, in prepare_metadata
#     self.metadata_directory = generate_metadata(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\operations\build\metadata.py", line 35, in generate_metadata
#     distinfo_dir = backend.prepare_metadata_for_build_wheel(metadata_dir)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 713, in prepare_metadata_for_build_wheel
#     return super().prepare_metadata_for_build_wheel(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 186, in prepare_metadata_for_build_wheel
#     return self._call_hook('prepare_metadata_for_build_wheel', {
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\pyproject_hooks\_impl.py", line 311, in _call_hook
#     self._subprocess_runner(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\subprocess.py", line 252, in runner
#     call_subprocess(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\subprocess.py", line 203, in call_subprocess
#     spinner.finish("done")
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 97, in finish
#     self._update(f"finished with status '{final_status}'")
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\spinners.py", line 85, in _update
#     logger.info("%s: %s", self._message, status)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: '%s: %s'
# Arguments: ('Preparing metadata (pyproject.toml)', "finished with status 'done'")
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 158, in _make_candidate_from_dist
#     base = self._installed_candidate_cache[dist.canonical_name]
# KeyError: 'requests'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
# ...
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 449, in run
#     installed = install_given_reqs(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\__init__.py", line 65, in install_given_reqs
#     logger.info("Attempting uninstall: %s", req_name)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Attempting uninstall: %s'
# Arguments: ('Password-package',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 449, in run
#     installed = install_given_reqs(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\__init__.py", line 67, in install_given_reqs
#     uninstalled_pathset = requirement.uninstall(auto_confirm=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\req_install.py", line 677, in uninstall
#     logger.info("Found existing installation: %s", dist)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Found existing installation: %s'
# Arguments: (Password-package 1.0.0 (c:\users\work\anaconda3\lib\site-packages),)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 449, in run
#     installed = install_given_reqs(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\__init__.py", line 67, in install_given_reqs
#     uninstalled_pathset = requirement.uninstall(auto_confirm=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\req_install.py", line 680, in uninstall
#     uninstalled_pathset.remove(auto_confirm, verbose)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\req_uninstall.py", line 372, in remove
#     logger.info("Uninstalling %s:", dist_name_version)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Uninstalling %s:'
# Arguments: ('Password-package-1.0.0',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 449, in run
#     installed = install_given_reqs(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\__init__.py", line 67, in install_given_reqs
#     uninstalled_pathset = requirement.uninstall(auto_confirm=True)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\req_install.py", line 680, in uninstall
#     uninstalled_pathset.remove(auto_confirm, verbose)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\req\req_uninstall.py", line 387, in remove
#     logger.info("Successfully uninstalled %s", dist_name_version)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Successfully uninstalled %s'
# Arguments: ('Password-package-1.0.0',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 177, in emit
#     self.console.print(renderable, overflow="ignore", crop=False, style=style)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 1719, in print
#     self._buffer.extend(new_segments)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 864, in __exit__
#     self._exit_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 822, in _exit_buffer
#     self._check_buffer()
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\console.py", line 2027, in _check_buffer
#     legacy_windows_render(buffer, LegacyWindowsTerm(self.file))
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_windows_renderer.py", line 19, in legacy_windows_render
#     term.write_text(text)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_vendor\rich\_win32_console.py", line 403, in write_text
#     self.write(text)
#   File "C:\Users\Work\anaconda3\lib\encodings\cp1251.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\xf6' in position 77: character maps to <undefined>
# Call stack:
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Work\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Work\anaconda3\Scripts\pip.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\main.py", line 79, in main
#     return command.main(cmd_args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 101, in main
#     return self._main(args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 223, in _main
#     return run(options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 248, in wrapper
#     return func(self, options, args)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 489, in run
#     write_output(
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\misc.py", line 338, in write_output
#     logger.info(msg, *args)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1446, in info
#     self._log(INFO, msg, args, **kwargs)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1589, in _log
#     self.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1599, in handle
#     self.callHandlers(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 1661, in callHandlers
#     hdlr.handle(record)
#   File "C:\Users\Work\anaconda3\lib\logging\__init__.py", line 952, in handle
#     self.emit(record)
#   File "C:\Users\Work\anaconda3\lib\site-packages\pip\_internal\utils\logging.py", line 179, in emit
#     self.handleError(record)
# Message: 'Successfully installed %s'
# Arguments: ('Password-package-1.0.0',)

# %%
import importlib
import sys

importlib.reload(sys)
sys.setdefaultencoding('utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_120\767772611.py in <module>
#       3
#       4 importlib.reload(sys)
# ----> 5 sys.setdefaultencoding('utf-8')
#
# AttributeError: module 'sys' has no attribute 'setdefaultencoding'
